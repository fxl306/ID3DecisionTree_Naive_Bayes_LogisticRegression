# %% [markdown]
# # Logistic Regression Analysis
# Feng Long
# 11/04/2022

# %% [markdown]
# # Problem (a):
# Create a table of the different metrics for naïve Bayes (m=0.01) and logistic regression (λ =0.01) on the different learning problems. Use a different cell for each dataset. For naïve Bayes, set the number of bins for continuous features to 10.

# %% [markdown]
# ## a1.Dataset Spam:
# - Naive Bayes:

# %%
# !python ../src/nbayes.py ../440data/spam 10 0.01
# Out:
# Accuracy:0.71
# Precision:0.74
# Recall:0.82
# Area under ROC:0.54
#
# Accuracy:0.71
# Precision:0.74
# Recall:0.82
# Area under ROC:0.54
#
# Accuracy:0.71
# Precision:0.74
# Recall:0.82
# Area under ROC:0.54
#
# Accuracy:0.70
# Precision:0.74
# Recall:0.79
# Area under ROC:0.56
#
# Accuracy:0.70
# Precision:0.74
# Recall:0.81
# Area under ROC:0.54
#
# ________________________________________________________________
# |   Model    |  Accuracy  |  Precision |   Recall   |     AUC    |
# -----------------------------------------------------------------
# | Bayes      |     0.7050 |     0.7426 |     0.8086 |     0.5442 |
# -----------------------------------------------------------------
# 0.000000 0.000000 2.000000
# 0.467872 0.808554 1.000000
# 1.000000 1.000000 0.000000
# Figure(640x480)

# %% [markdown]
# - Logistic regression

# %%
# !python ../src/logreg.py ../440data/spam 0.01
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.44
# Precision:0.63
# Recall:0.27
# Area under ROC:0.50
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.63
# Precision:0.63
# Recall:0.98
# Area under ROC:0.51
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.63
# Precision:0.63
# Recall:0.98
# Area under ROC:0.51
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.62
# Precision:0.63
# Recall:0.94
# Area under ROC:0.52
# ...

# %% [markdown]
# ## a2.Dataset Voting
# - Naive Bayes:

# %%
# !python ../src/nbayes.py ../440data/voting 10 0.01
# Out:
# Accuracy:0.98
# Precision:0.97
# Recall:0.97
# Area under ROC:0.97
#
# Accuracy:0.99
# Precision:1.00
# Recall:0.97
# Area under ROC:0.97
#
# Accuracy:0.98
# Precision:0.95
# Recall:1.00
# Area under ROC:1.00
#
# Accuracy:0.94
# Precision:0.93
# Recall:0.95
# Area under ROC:0.97
#
# Accuracy:0.99
# Precision:1.00
# Recall:0.97
# Area under ROC:0.94
#
# ________________________________________________________________
# |   Model    |  Accuracy  |  Precision |   Recall   |     AUC    |
# -----------------------------------------------------------------
# | Bayes      |     0.9748 |     0.9701 |     0.9745 |     0.9702 |
# -----------------------------------------------------------------
# 0.000000 0.000000 2.000000
# 0.024590 0.974490 1.000000
# 1.000000 1.000000 0.000000
# Figure(640x480)

# %% [markdown]
# - Logistic regression

# %%
# !python ../src/logreg.py ../440data/voting 0.01
# Out:
# Accuracy:0.97
# Precision:0.97
# Recall:0.95
# Area under ROC:1.00
#
# Accuracy:0.99
# Precision:1.00
# Recall:0.97
# Area under ROC:1.00
#
# Accuracy:1.00
# Precision:1.00
# Recall:1.00
# Area under ROC:1.00
#
# Accuracy:0.99
# Precision:1.00
# Recall:0.97
# Area under ROC:0.98
#
# Accuracy:0.99
# Precision:1.00
# Recall:0.97
# Area under ROC:0.99
# ________________________________________________________________
# |   Model    |  Accuracy  |  Precision |   Recall   |     AUC    |
# -----------------------------------------------------------------
# | LogReg     |     0.9863 |     0.9947 |     0.9745 |     0.9944 |
# -----------------------------------------------------------------
# 0.000000 0.000000 2.000000
# 0.004098 0.974490 1.000000
# 1.000000 1.000000 0.000000
# Figure(640x480)

# %% [markdown]
# ## a3.Dataset Volcanoes:
# - Naive Bayes:

# %%
# !python ../src/nbayes.py ../440data/volcanoes 10 0.01
# Out:
# Accuracy:0.65
# Precision:0.48
# Recall:0.82
# Area under ROC:0.77
#
# Accuracy:0.65
# Precision:0.48
# Recall:0.87
# Area under ROC:0.77
#
# Accuracy:0.63
# Precision:0.46
# Recall:0.80
# Area under ROC:0.76
#
# Accuracy:0.59
# Precision:0.43
# Recall:0.83
# Area under ROC:0.73
#
# Accuracy:0.63
# Precision:0.46
# Recall:0.81
# Area under ROC:0.75
#
# ________________________________________________________________
# |   Model    |  Accuracy  |  Precision |   Recall   |     AUC    |
# -----------------------------------------------------------------
# | Bayes      |     0.6284 |     0.4629 |     0.8263 |     0.7561 |
# -----------------------------------------------------------------
# 0.000000 0.000000 2.000000
# 0.468000 0.826265 1.000000
# 1.000000 1.000000 0.000000
# Figure(640x480)

# %% [markdown]
# - Logistic regression

# %%
# !python ../src/logreg.py ../440data/volcanoes 0.01
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.36
# Precision:0.34
# Recall:1.00
# Area under ROC:0.53
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.83
# Precision:0.94
# Recall:0.50
# Area under ROC:0.74
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.67
# Precision:0.00
# Recall:0.00
# Area under ROC:0.50
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.36
# Precision:0.34
# Recall:0.98
# Area under ROC:0.52
# ...

# %% [markdown]
# # Problem (b):
# Examine the effect of λ on logistic regression. Do this by graphing area under ROC across λ=0, 0.001, 0.01, and 0.1 on the given datasets.
#
# we use dataset voting with logistic regress with $\lambda$ =0, 0.01, 0.1, 1

# %% [markdown]
# - b1. $\lambda = 0$

# %%
# !python ../src/logreg.py ../440data/volcanoes 0
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.67
# /Users/fenglong/Documents/GitHub/csds440-f22-6/src/util.py:168: RuntimeWarning: invalid value encountered in long_scalars
#   return tp / (y_hat == 1).sum()
# Precision:nan
# Recall:0.00
# Area under ROC:0.50
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.73
# Precision:0.56
# Recall:0.86
# Area under ROC:0.76
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.79
# Precision:0.66
# Recall:0.78
# Area under ROC:0.79
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
# ...

# %% [markdown]
# ![](lmb0_volcanoes.png)

# %% [markdown]
# - b2. $\lambda = 0.001$

# %%
# !python ../src/logreg.py ../440data/volcanoes 0.001
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.37
# Precision:0.34
# Recall:1.00
# Area under ROC:0.53
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.67
# /Users/fenglong/Documents/GitHub/csds440-f22-6/src/util.py:168: RuntimeWarning: invalid value encountered in long_scalars
#   return tp / (y_hat == 1).sum()
# Precision:nan
# Recall:0.00
# Area under ROC:0.50
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.67
# Precision:0.50
# Recall:0.94
# Area under ROC:0.74
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
# ...

# %% [markdown]
# ![](0.001_volcanoes.png)

# %% [markdown]
# - b3. $\lambda = 0.01$

# %%
# !python ../src/logreg.py ../440data/volcanoes 0.01
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.36
# Precision:0.34
# Recall:1.00
# Area under ROC:0.53
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.83
# Precision:0.94
# Recall:0.50
# Area under ROC:0.74
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.67
# Precision:0.00
# Recall:0.00
# Area under ROC:0.50
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.36
# Precision:0.34
# Recall:0.98
# Area under ROC:0.52
# ...

# %% [markdown]
# ![](lmd0.01_volcanoes.png)

# %% [markdown]
# - b4. $\lambda = 0.1$

# %%
# !python ../src/logreg.py ../440data/volcanoes 0.1
# Out:
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
# Accuracy:0.60
# Precision:0.44
# Recall:0.90
# Area under ROC:0.68
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.78
# Precision:0.94
# Recall:0.35
# Area under ROC:0.67
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.74
# Precision:0.91
# Recall:0.22
# Area under ROC:0.60
# /Users/fenglong/Documents/GitHub/csds440-f22-6/notebooks/../src/logreg.py:56: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-(z + b)))
#
# Accuracy:0.67
# ...

# %% [markdown]
# ![](lmd0.1%20_volcanoes.png)

# %% [markdown]
# Conclusion:based on above experiment result, when we increase $\lambda$ from 0 to 0.1, a increasing AUC is observed, indicating an increase in the accuracy as well.
